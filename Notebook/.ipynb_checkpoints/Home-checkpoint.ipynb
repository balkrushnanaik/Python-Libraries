# %%
print("Hello World")
# Out:
# Hello World

# %%
num1 = 10
num2 = 50

sum = num1 + num2 
print(sum)
# Out:
# 60

# %%
# Find area of rectangle

length = int(input("Enter the length of rectangle"))
width = int(input("Enter the width of rectangle"))

area_of_rectangle = length * width
print(area_of_rectangle)
# Out:
# Enter the length of rectangle 10
# Enter the width of rectangle 29
# 290

# %%
# Find area of circle

# area of circle = Pi * r**2

r = 12
pi = 3.14

print(pi*r*r)
# Out:
# 452.15999999999997

# %%
# Swap two numbers

a = 2
b = 4

a = a + b   # (a = 6)
b = a - b   # ( 6-4 = 2)
a = a - b    # (6 - 2= 4)

print(a)
print(b)
# Out:
# 4
# 2

# %%
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
